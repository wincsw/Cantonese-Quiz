# %%
import pandas as pd
wordCount = pd.read_csv('existingwordcount.csv', encoding ='utf-8')
wordCount.head()
# Out:
#   Source  https://words.hk/faiman/analysis/existingwordcount/
# 0      B                                               1969
# 1      の                                                 30
# 2      㗎                                                934
# 3      一                                              40680
# 4     一下                                                935

# %%
wordCount.columns = ['Word', 'Count']
wordCount
# Out:
#       Word  Count
# 0        B   1969
# 1        の     30
# 2        㗎    934
# 3        一  40680
# 4       一下    935
# ...    ...    ...
# 32462   後期      1
# 32463   步兵      3
# 32464  清真寺      1
# 32465   督工      1
# 32466   藏書      1
#
# [32467 rows x 2 columns]

# %%
wordCount = wordCount.sort_values(by=['Count'], ascending = False)
wordCount
# Out:
#        Word  Count
# 150       係  58304
# 760       我  44818
# 3         一  40680
# 396       唔  34705
# 432       嘅  26992
# ...     ...    ...
# 16416    睇症      1
# 26410  小家碧玉      1
# 16417    短途      1
# 26408    對質      1
# 32466    藏書      1
#
# [32467 rows x 2 columns]
