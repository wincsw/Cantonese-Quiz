# %%
import pandas as pd
import pycantonese
# Data source: https://words.hk/ 


wordCount = pd.read_csv('existingwordcount.csv', encoding ='utf-8')
wordCount.head()
# Out:
#   Source  https://words.hk/faiman/analysis/existingwordcount/
# 0      B                                               1969
# 1      の                                                 30
# 2      㗎                                                934
# 3      一                                              40680
# 4     一下                                                935

# %%
wordCount.columns = ['Word', 'Count']
wordCount
# Out:
#       Word  Count
# 0        B   1969
# 1        の     30
# 2        㗎    934
# 3        一  40680
# 4       一下    935
# ...    ...    ...
# 32462   後期      1
# 32463   步兵      3
# 32464  清真寺      1
# 32465   督工      1
# 32466   藏書      1
#
# [32467 rows x 2 columns]

# %%
wordCount = wordCount.sort_values(by=['Count'], ascending = False)
filter = (wordCount['Word'].str.len() >= 2)
wordCount.loc[filter][100:150]
# Out:
#      Word  Count
# 5159   女仔    822
# 2727   結果    817
# 4224   呢度    811
# 331    另一    792
# 1490   記得    781
# 151    係呢    778
# 909    更加    776
# 5449   港人    775
# 5533   發生    773
# 3022   而家    769
# 1690   需要    743
# 1431   落去    736
# 2871   出現    735
# 4030   粵語    727
# 433    嘅嘢    723
# 1851   唔識    718
# 3354   不如    716
# 5850  香港人    715
# 3262   唔同    713
# 926    有時    712
# 3107   又係    704
# 118    任何    700
# 1922   所謂    689
# 4275   無人    688
# 1629   重要    688
# 2923   廣東    668
# 36     上面    665
# 1748   點樣    663
# 2511   例如    663
# 25     一邊    660
# 2093   語言    659
# 2672   機會    658
# 3559  一個人    655
# 4643   社會    654
# 3583   仲要    650
# 3713   決定    650
# 4186   開心    648
# 2600   就好    646
# 338    只要    644
# 3663   慢慢    639
# 3151   普通    636
# 3101   分鐘    632
# 1222   相信    632
# 3399   定係    629
# 2723   簡單    626
# 3550   ge    623
# 15     一日    616
# 660    幾多    616
# 1377   能夠    614
# 7986   甚麼    606

# %%
wordCount["Word"][150]
# Out:
# '係'

# %%
corpus = pycantonese.hkcancor()
test = corpus.search(character=wordCount["Word"][150])
test[:5]
# Out:
# [Token(word='係', pos='V', jyutping='hai6', mor=None, gloss=None, gra=None),
#  Token(word='係', pos='V', jyutping='hai6', mor=None, gloss=None, gra=None),
#  Token(word='但係', pos='C', jyutping='daan6hai6', mor=None, gloss=None, gra=None),
#  Token(word='淨係', pos='D', jyutping='zing6hai6', mor=None, gloss=None, gra=None),
#  Token(word='係', pos='V', jyutping='hai6', mor=None, gloss=None, gra=None)]
